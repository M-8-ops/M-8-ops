# %% [markdown]
# <a href="https://colab.research.google.com/github/M-8-ops/M-8-ops/blob/main/BreastCancerDiagnosisCleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# BREAST CANCER DATA PREPARATION AND ANALYSIS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv("/content/Breast_GSE45827.csv")

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151 entries, 0 to 150
# Columns: 54677 entries, samples to AFFX-TrpnX-M_at
# dtypes: float64(54675), int64(1), object(1)
# memory usage: 63.0+ MB

# %%
dataset.shape
# Out:
# (151, 54677)

# %%
dataset.head(10)
# Out:
#    samples   type  1007_s_at   1053_at    117_at    121_at  1255_g_at  \
# 0       84  basal   9.850040  8.097927  6.424728  7.353027   3.029122
# 1       85  basal   9.861357  8.212222  7.062593  7.685578   3.149468
# 2       87  basal  10.103478  8.936137  5.735970  7.687822   3.125931
# 3       90  basal   9.756875  7.357148  6.479183  6.986624   3.181638
# 4       91  basal   9.408330  7.746404  6.693980  7.333426   3.169923
# 5       92  basal   7.505488  8.802820  6.235074  7.202227   2.987976
# 6       93  basal  10.422371  8.933601  5.630488  6.881770   3.097372
# 7       94  basal  10.190705  7.813057  6.701297  6.921350   3.140037
# 8       99  basal  10.256077  7.796936  6.725722  7.098550   3.139031
# 9      101  basal   9.053138  8.043154  7.655891  6.900599   2.988920
#
#     1294_at   1316_at   1320_at  ...  AFFX-r2-Ec-bioD-3_at  \
# 0  6.880079  4.963740  4.408328  ...             12.229711
# 1  7.542283  5.129607  4.584418  ...             12.178531
# ...

# %%
#Deleting columns
dataset.drop(columns=['samples'],inplace=True)

# %%
#Finding and deleting Nulls:
dataset.dropna(axis='index',how='any')
dataset.dropna(axis='columns',how='any')
# Out:
#           type  1007_s_at   1053_at    117_at    121_at  1255_g_at   1294_at  \
# 0        basal   9.850040  8.097927  6.424728  7.353027   3.029122  6.880079
# 1        basal   9.861357  8.212222  7.062593  7.685578   3.149468  7.542283
# 2        basal  10.103478  8.936137  5.735970  7.687822   3.125931  6.562369
# 3        basal   9.756875  7.357148  6.479183  6.986624   3.181638  7.802344
# 4        basal   9.408330  7.746404  6.693980  7.333426   3.169923  7.610457
# ..         ...        ...       ...       ...       ...        ...       ...
# 146  luminal_B  10.392638  7.334408  6.848586  7.020486   3.228065  7.815439
# 147  luminal_B  10.930875  8.415294  5.906827  7.753572   3.270557  7.367931
# 148  luminal_B  11.027098  7.180876  6.304736  7.641197   3.206950  8.569296
# 149  luminal_B  10.444395  7.525153  5.964460  7.825939   3.384147  7.268454
# 150  luminal_B  11.345817  7.379299  5.891172  7.394586   3.183420  7.792885
#
# ...

# %%
#Changing index of the first column to last
first_col = dataset.pop(dataset.columns[0])
dataset[dataset.columns[-1]] = first_col

# %%
dataset.shape
# Out:
# (151, 54675)

# %%
pd.set_option('display.max_columns',151)

# %%
dataset
# Out:
#      1007_s_at   1053_at    117_at    121_at  1255_g_at   1294_at   1316_at  \
# 0     9.850040  8.097927  6.424728  7.353027   3.029122  6.880079  4.963740
# 1     9.861357  8.212222  7.062593  7.685578   3.149468  7.542283  5.129607
# 2    10.103478  8.936137  5.735970  7.687822   3.125931  6.562369  4.813449
# 3     9.756875  7.357148  6.479183  6.986624   3.181638  7.802344  5.490982
# 4     9.408330  7.746404  6.693980  7.333426   3.169923  7.610457  5.372469
# ..         ...       ...       ...       ...        ...       ...       ...
# 146  10.392638  7.334408  6.848586  7.020486   3.228065  7.815439  5.448470
# 147  10.930875  8.415294  5.906827  7.753572   3.270557  7.367931  5.906849
# 148  11.027098  7.180876  6.304736  7.641197   3.206950  8.569296  5.823146
# 149  10.444395  7.525153  5.964460  7.825939   3.384147  7.268454  5.245072
# 150  11.345817  7.379299  5.891172  7.394586   3.183420  7.792885  5.355978
#
# ...

# %%
#Renaming the dataset
dataset.rename(columns={'AFFX-TrpnX-M_at':'type'},inplace=True)

# %%
#Exporting the prepared dataset to a csv

#Writing to a csv
dataset.to_csv('Documents\Breast.csv')
